# %%
import numpy, sklearn
import pandas as pd
import os

# %%
os.chdir('./data')

# %% [markdown]
# Read all csvs into dataframe objects for each PreRanger Class.

# %%
def csv2dataframe(fileobj):
    with open(fileobj, 'r') as f:
         return pd.read_csv(f, header=1)

# %%
df = csv2dataframe('01-15.csv')

# %%
class1
# Out:
#                                     RN#                    NAME  RANK  MOS  \
# 0                                   NaN                     NaN   NaN  NaN
# 1                                     1  ALEXANDER, CHRISTOPHER   SPC  11B
# 2                                     2       ANGUIANO, GREGORY   SGT  42A
# 3                                     3        ARENIVAS, CARLOS   PFC  13D
# 4                                     5           BOCK, GREGORY   PFC  11B
# 5                                     9              CHO, YOUNG   SGT  92Y
# 6                                    10          CLARK, WILLIAM  2LT   13A
# 7                                    13       GONZALES, MATTHEW   SPC  94A
# 8                                    15        HARSFORD, COZZIE   PFC  11B
# 9                                    18          JUDGE, RAYMOND   SPC  11B
# 10                                   19         LOVINS, TRENTON   SPC  11B
# ...
